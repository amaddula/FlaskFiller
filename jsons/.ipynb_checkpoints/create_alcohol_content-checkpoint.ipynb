# %%
#alcohol content calculations

# %%
import json
from collections import defaultdict
from collections import Counter
import math
import numpy as np

with open('cossim_decimals.json', 'r') as fr:
    drinks_dict = json.load(fr)
    
with open('ingredients_alccontents_relevant.json', 'r') as fr:
    alc_contents = json.load(fr)

# %%
drinks_by_alcohol_content_dic = {}

# %%
for drink, ingredients in drinks_dict.items():
    alc_acc = 0
    total_acc = 0
    for ingr in ingredients:
        total_acc += ingr[1]
        alc_percentage = alc_contents[ingr[0]]
        alc_acc += ingr[1] * alc_percentage
    drink_perc = alc_acc/(total_acc+1)
    drinks_by_alcohol_content_dic[drink] = drink_perc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8894de100656> in <module>()
#       5         total_acc += ingr[1]
#       6         alc_percentage = alc_contents[ingr[0]]
# ----> 7         alc_acc += ingr[1] * alc_percentage
#       8     drink_perc = alc_acc/(total_acc+1)
#       9     drinks_by_alcohol_content_dic[drink] = drink_perc
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print(drinks_by_alcohol_content_dic)
# Out:
# {'Absolutly Screwed': -0.5, "Redhead's Nipple": -0.6666666666666666, 'Cinnamon Toast Crunch': -0.75, 'Apfel Orange': -0.3111111111111111, "Jack Daniel's Lynchburg Lemonade": -0.391304347826087, 'Army Green': -0.75, 'JTDelight': -0.6774193548387096, 'Hurts You Right Here!': -0.2625, 'Sammy Slammer': -0.6363636363636364, 'Carmel Apple': 0.09, 'Rain Man': -0.54375, 'Arizona Stingers': -0.9375, 'Carolina': -0.8, 'Black Cow #3': -0.375, 'Fruit Loop #2': -0.23666666666666666, 'The Evil Blue Thing': -0.425, 'Alizé': -0.6266666666666666, 'Slow Screw up against a Red Wall': -0.9, 'Raging Indian': -0.5714285714285715, 'Good Fortune': -0.7905555555555556, 'Barbary Coast': -0.7142857142857143, 'Watermelon schnapps': -0.4666666666666666, 'Beam Scream': -0.2625, 'Purple Motherfucker': -0.7324999999999999, 'Yellow Birdie': -0.2222222222222222, 'Quick-sand': -0.8014634146341463, 'Vodka Stinger': -0.6666666666666666, 'Green Eyed Blonde': -0.09666666666666666, 'Terror From the Deep': -0.7272727272727273, 'North Polar': -0.8181818181818182, 'Absolute HB': -0.6666666666666666, 'Parappa the Drunk Rappa': 0.003000000000000012, 'Summertime': -0.5294117647058824, 'Mocha Martini': -0.8, 'Frenchie': -0.75, 'Iced tea': -0.9803921568627451, 'Thorazine': -0.24900000000000003, 'Purple Shroud': -0.43571428571428567, 'Ostrich Shit': -0.0975609756097561, 'Green Goblin': -0.4081081081081081, 'Lime Lizard': -0.6666666666666666, 'Pitbull on Crack #1': -0.48107142857142854, 'Green Creme de Menthe': -0.6, 'Horny Bull #2': -0.6, 'The Feckin Bolox': -0.366, 'Glitch': -0.608, 'Black Cactus': -0.1625, 'Bourble': -0.04999999999999999, 'Kickstand': -0.5828571428571429, "Fin N' Tonic": -0.5, 'Chambord raspberry liqueur': -0.8, 'Apple cider': -0.14470588235294118, 'Goldschlager Lemondrop': -0.75, 'Pina Colada #1': -0.42857142857142855, 'Wu Wu': -0.5833333333333334, 'Pink Fix': -0.8260869565217391, 'Pink Penocha': -0.6781704781704782, 'Rocky Mountain Bear Fucker': -0.5, 'Hunter Mountain': -0.47523809523809524, 'Mellon Collie and The Infinite Gladness': -0.4166666666666667, 'Greek Sex On The Beach': -0.9375, 'Southern Sparkler': -0.4166666666666667, 'Jagnog': -0.8571428571428571, 'Red Rudolph': -0.2, 'Catfish': -0.6666666666666666, 'Burning Sun': -0.23076923076923078, 'Curacao': -0.37365853658536585, 'White Splash': -0.21428571428571427, 'Screw-Up': -0.3, 'Pink Lemonade': -0.8, 'Tirade': -0.6666666666666666, 'Shrewsbury Slammer': -0.3513636363636364, 'Malibu Seven': -0.375, 'Cement Kicker': 0.01781250000000001, 'Creamy Rum Liqueur': -0.38235294117647056, 'Purple Heart': -0.75, 'Beam Me Up Scotty': -0.11599999999999999, 'Mango Mint': -0.8518518518518519, "Daylon's Bedtime": -0.46153846153846156, 'Opening Cocktail': -0.11428571428571425, 'Upper Cut': -0.4848484848484848, "Mafia's Kiss": -0.5439999999999999, 'Creamsicle': -0.8571428571428571, 'Disco Ball': -0.6666666666666666, 'L.A.P.D. Nightshift': -0.4636363636363636, 'Jens Special': -0.20689655172413796, 'The Dukes Of Hazzard Tonic': -0.9047619047619048, 'Pink Panty Pulldowns #2': -0.2649842271293375, 'Jackhammer': -0.24, 'Desert Water': -0.3333333333333333, 'Red Velvet': -0.36507936507936506, 'Greenback': -0.7777777777777778, 'Firewater': -0.6666666666666666, 'Nadal furia': -0.8181818181818182, 'B-53 #2': -0.8, 'Milwaukee Stop Light': -0.4636363636363636, 'Jägermonster': -0.8888888888888888, 'Cramit': 0.06461538461538462, 'Citrus Surprise': -0.8571428571428571, 'Corona': -0.9310344827586207, 'Mountain Dang': -0.8571428571428571, 'Patriotic Blow': -0.19090909090909092, 'Pimp Punch': -0.08888888888888889, 'Neutron Bomb': -0.11333333333333333, 'Twinkle My Lights': -0.12533333333333332, 'Golden Daze': -0.75, "Leah's Last Hope #2": -0.24727272727272726, 'Cherry Martinsen': -0.3076923076923077, 'Electric Marcucci': -0.19999999999999998, "Entwistle's Error": -0.3333333333333333, 'Frozen Bird': -0.5, 'Fig': -0.3333333333333333, 'Bruised Heart': -0.5, 'Tiger Tail': -0.8181818181818182, 'Peachy Comfort': -0.9375, 'Snake Piss': -0.92 ...

# %%
import json
data = json.dumps(drinks_dict, indent=4, separators=(',', ': '))
with open("drinks_with_alcohol_content.json", "w") as f:
    f.write(data)
